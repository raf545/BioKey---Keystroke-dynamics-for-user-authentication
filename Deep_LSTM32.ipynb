# %% [markdown]
# # **2LSTM32**
#
#
# ---
#
# This is The 2xLSTM32 model build and train file. when runing this file you would get at the end the saved traind model file.
#
# under this section you can find all the global variables, imports and settings.
#
# ![2LSTM-01-min.jpeg](data:image/jpeg;base64,...)

# %%
# %tensorflow_version 2.x
from sklearn.model_selection import validation_curve
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from keras import layers
import os
import math
from keras.callbacks import LearningRateScheduler
import ast
import h5py

# %%
train_data = np.array([])
train_labels = np.array([])
val0_data = np.array([])
val0_labels = np.array([])
val1_data = np.array([])
val1_labels = np.array([])
input_shape = (40,6)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data loading
#
#
# ---
#
# ***Description:*** Load the data from a given directory and aplies Sliding window over it with the given size ws.
#
# ***Output:*** no returns, load in to the global variables the data from the h5 file.
#
# ***Algorithm:*** first we load the rain data from the given h5 file. then we take the first 1000 tupels to be the testing data. for lable 0 and 1 to `val0` and `val1` respectivly.
# Then we reshape the data to an array of window where every window is of size ws given to the function.
# and we save all the first 1000 in the test variables, bothe data and lables.
#
# ![SWin.png](data:image/png;base64,...)

# %% [markdown]
# **In order to run this notebook you have to mount your google drive to colab or upload the data sets to colab framework and copy the path of the files.**

# %%
with h5py.File('/content/drive/MyDrive/BioKey/Data_HDF_files/Rand_WS40.h5','r') as hdf:
  data = hdf.get('train_data')
  train_data = np.array(data)
  data = hdf.get('train_labels')
  train_labels = np.array(data)

# %%
for i in range(1000):
  if train_labels[i] == 0:
    val0_data = np.append(val0_data,train_data[i])

val0_labels = np.empty(int(val0_data.shape[0]/(40*6)))
val0_labels.fill(0)

for i in range(1000):
  if train_labels[i] == 1:
    val1_data = np.append(val1_data,train_data[i])

val1_labels = np.empty(int(val1_data.shape[0]/(40*6)))
val1_labels.fill(1)


val1_data = val1_data.reshape(int(val1_labels.shape[0]),40,6)
val0_data = val0_data.reshape(int(val0_labels.shape[0]),40,6)

train_data = train_data[1000:]
train_labels = train_labels[1000:]

# %% [markdown]
# #Model
#
# ---
# In the second architecture we tried to abandon the first layer of the 1D convolution and replace it with an LSTM layer. Both layers has 32 units and a dropout of 0.5 after each layer. Then the output of the second LSTM is flatten and connected to a fully connected layer with 2 neurons that use a Softmax activation function

# %%
model = keras.models.Sequential()
model.add(layers.CuDNNLSTM(32 , return_sequences=True, input_shape = input_shape))
model.add(layers.Dropout(0.5))
model.add(layers.CuDNNLSTM(32, return_sequences=True))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(2, activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  cu_dnnlstm (CuDNNLSTM)      (None, 40, 32)            5120
#
#  dropout (Dropout)           (None, 40, 32)            0
#
#  cu_dnnlstm_1 (CuDNNLSTM)    (None, 40, 32)            8448
#
#  dropout_1 (Dropout)         (None, 40, 32)            0
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense (Dense)               (None, 2)                 2562
#
# =================================================================
# Total params: 16,130
# Trainable params: 16,130
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# The Adam optimizer was best fit for our clasification job so we chose him. we initialized the learning rate to be 0 because as we will see we used a changing learning rate scedual so the initialization of the learning rate should be 0.

# %%
from keras.backend import binary_crossentropy
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optim = keras.optimizers.Adam(learning_rate=0.0)
metrics = ["accuracy"]

# %% [markdown]
# Batch size of 32 was the best performing batch size that we tride between 8 and 128. The number of epochs is 150 because in this number we reach saturation and there is no point in continuing to teach the model.

# %%
model.compile(loss=loss, optimizer=optim,metrics=metrics)
batchSize = 32
epochs = 150

# %% [markdown]
# As explaind above we used a learning decay so the initial learning rate is 0.0001, and at the 100th epoch we derive the learning rate by 10 to be 0.00001.

# %%
def step_decay(epoch):
	initial_lrate = 0.0001
	drop = 0.1
	epochs_drop = 100.0
	lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
	return lrate

# %%
lrate = LearningRateScheduler(step_decay)
callbacks_list = [lrate]

# %% [markdown]
# # Training
#
# ---
# We split our data in ration of 9:1 witch means that 90% of the data goes to the training process and 10% goes to the validation process. this way we can better analize the learning stage of our models.

# %%
with tf.device('/device:GPU:0'):
  model.fit(train_data,train_labels,batch_size = batchSize ,validation_split = 0.1, callbacks=callbacks_list,epochs=epochs,shuffle=True)
# Out:
# Epoch 1/150
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 1172/1172 [==============================] - 11s 5ms/step - loss: 0.6166 - accuracy: 0.6613 - val_loss: 0.5743 - val_accuracy: 0.7073 - lr: 1.0000e-04
# Epoch 2/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5736 - accuracy: 0.6976 - val_loss: 0.5569 - val_accuracy: 0.7121 - lr: 1.0000e-04
# Epoch 3/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5637 - accuracy: 0.7048 - val_loss: 0.5496 - val_accuracy: 0.7154 - lr: 1.0000e-04
# Epoch 4/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5572 - accuracy: 0.7077 - val_loss: 0.5539 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Epoch 5/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5526 - accuracy: 0.7107 - val_loss: 0.5365 - val_accuracy: 0.7238 - lr: 1.0000e-04
# Epoch 6/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5445 - accuracy: 0.7157 - val_loss: 0.5257 - val_accuracy: 0.7257 - lr: 1.0000e-04
# Epoch 7/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5367 - accuracy: 0.7210 - val_loss: 0.5198 - val_accuracy: 0.7344 - lr: 1.0000e-04
# Epoch 8/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5305 - accuracy: 0.7257 - val_loss: 0.5186 - val_accuracy: 0.7361 - lr: 1.0000e-04
# Epoch 9/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5271 - accuracy: 0.7273 - val_loss: 0.5148 - val_accuracy: 0.7394 - lr: 1.0000e-04
# Epoch 10/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5243 - accuracy: 0.7299 - val_loss: 0.5090 - val_accuracy: 0.7440 - lr: 1.0000e-04
# Epoch 11/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5207 - accuracy: 0.7314 - val_loss: 0.5089 - val_accuracy: 0.7414 - lr: 1.0000e-04
# Epoch 12/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5157 - accuracy: 0.7352 - val_loss: 0.5079 - val_accuracy: 0.7421 - lr: 1.0000e-04
# Epoch 13/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5149 - accuracy: 0.7361 - val_loss: 0.4974 - val_accuracy: 0.7483 - lr: 1.0000e-04
# Epoch 14/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5098 - accuracy: 0.7399 - val_loss: 0.4943 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 15/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5069 - accuracy: 0.7412 - val_loss: 0.4922 - val_accuracy: 0.7517 - lr: 1.0000e-04
# Epoch 16/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.5032 - accuracy: 0.7444 - val_loss: 0.4865 - val_accuracy: 0.7560 - lr: 1.0000e-04
# Epoch 17/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4979 - accuracy: 0.7450 - val_loss: 0.4880 - val_accuracy: 0.7526 - lr: 1.0000e-04
# Epoch 18/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4910 - accuracy: 0.7515 - val_loss: 0.4726 - val_accuracy: 0.7680 - lr: 1.0000e-04
# Epoch 19/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4796 - accuracy: 0.7603 - val_loss: 0.4605 - val_accuracy: 0.7800 - lr: 1.0000e-04
# Epoch 20/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4692 - accuracy: 0.7655 - val_loss: 0.4498 - val_accuracy: 0.7908 - lr: 1.0000e-04
# Epoch 21/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4616 - accuracy: 0.7736 - val_loss: 0.4543 - val_accuracy: 0.7791 - lr: 1.0000e-04
# Epoch 22/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4552 - accuracy: 0.7793 - val_loss: 0.4329 - val_accuracy: 0.7992 - lr: 1.0000e-04
# Epoch 23/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4453 - accuracy: 0.7864 - val_loss: 0.4250 - val_accuracy: 0.8016 - lr: 1.0000e-04
# Epoch 24/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4354 - accuracy: 0.7936 - val_loss: 0.4240 - val_accuracy: 0.8028 - lr: 1.0000e-04
# Epoch 25/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4300 - accuracy: 0.7963 - val_loss: 0.4078 - val_accuracy: 0.8156 - lr: 1.0000e-04
# Epoch 26/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4229 - accuracy: 0.8018 - val_loss: 0.4193 - val_accuracy: 0.8048 - lr: 1.0000e-04
# Epoch 27/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4189 - accuracy: 0.8048 - val_loss: 0.4075 - val_accuracy: 0.8184 - lr: 1.0000e-04
# Epoch 28/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4142 - accuracy: 0.8107 - val_loss: 0.3949 - val_accuracy: 0.8201 - lr: 1.0000e-04
# Epoch 29/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4093 - accuracy: 0.8142 - val_loss: 0.3914 - val_accuracy: 0.8261 - lr: 1.0000e-04
# Epoch 30/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4054 - accuracy: 0.8145 - val_loss: 0.4010 - val_accuracy: 0.8139 - lr: 1.0000e-04
# Epoch 31/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.4002 - accuracy: 0.8189 - val_loss: 0.3796 - val_accuracy: 0.8336 - lr: 1.0000e-04
# Epoch 32/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3966 - accuracy: 0.8207 - val_loss: 0.3737 - val_accuracy: 0.8365 - lr: 1.0000e-04
# Epoch 33/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3913 - accuracy: 0.8246 - val_loss: 0.3681 - val_accuracy: 0.8401 - lr: 1.0000e-04
# Epoch 34/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3854 - accuracy: 0.8276 - val_loss: 0.3640 - val_accuracy: 0.8357 - lr: 1.0000e-04
# Epoch 35/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3819 - accuracy: 0.8274 - val_loss: 0.3652 - val_accuracy: 0.8379 - lr: 1.0000e-04
# Epoch 36/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3782 - accuracy: 0.8307 - val_loss: 0.3618 - val_accuracy: 0.8415 - lr: 1.0000e-04
# Epoch 37/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3733 - accuracy: 0.8318 - val_loss: 0.3504 - val_accuracy: 0.8516 - lr: 1.0000e-04
# Epoch 38/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3717 - accuracy: 0.8338 - val_loss: 0.3566 - val_accuracy: 0.8453 - lr: 1.0000e-04
# Epoch 39/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3671 - accuracy: 0.8360 - val_loss: 0.3545 - val_accuracy: 0.8461 - lr: 1.0000e-04
# Epoch 40/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3652 - accuracy: 0.8391 - val_loss: 0.3429 - val_accuracy: 0.8542 - lr: 1.0000e-04
# Epoch 41/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3611 - accuracy: 0.8406 - val_loss: 0.3550 - val_accuracy: 0.8422 - lr: 1.0000e-04
# Epoch 42/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3579 - accuracy: 0.8415 - val_loss: 0.3630 - val_accuracy: 0.8403 - lr: 1.0000e-04
# Epoch 43/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3539 - accuracy: 0.8425 - val_loss: 0.3370 - val_accuracy: 0.8554 - lr: 1.0000e-04
# Epoch 44/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3507 - accuracy: 0.8446 - val_loss: 0.3362 - val_accuracy: 0.8552 - lr: 1.0000e-04
# Epoch 45/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3488 - accuracy: 0.8458 - val_loss: 0.3306 - val_accuracy: 0.8600 - lr: 1.0000e-04
# Epoch 46/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3445 - accuracy: 0.8479 - val_loss: 0.3230 - val_accuracy: 0.8641 - lr: 1.0000e-04
# Epoch 47/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3431 - accuracy: 0.8500 - val_loss: 0.3362 - val_accuracy: 0.8528 - lr: 1.0000e-04
# Epoch 48/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3397 - accuracy: 0.8506 - val_loss: 0.3350 - val_accuracy: 0.8537 - lr: 1.0000e-04
# Epoch 49/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3380 - accuracy: 0.8516 - val_loss: 0.3224 - val_accuracy: 0.8619 - lr: 1.0000e-04
# Epoch 50/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3357 - accuracy: 0.8537 - val_loss: 0.3292 - val_accuracy: 0.8573 - lr: 1.0000e-04
# Epoch 51/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3312 - accuracy: 0.8549 - val_loss: 0.3243 - val_accuracy: 0.8564 - lr: 1.0000e-04
# Epoch 52/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3318 - accuracy: 0.8545 - val_loss: 0.3483 - val_accuracy: 0.8434 - lr: 1.0000e-04
# Epoch 53/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3287 - accuracy: 0.8559 - val_loss: 0.3291 - val_accuracy: 0.8554 - lr: 1.0000e-04
# Epoch 54/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3224 - accuracy: 0.8610 - val_loss: 0.3474 - val_accuracy: 0.8446 - lr: 1.0000e-04
# Epoch 55/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3227 - accuracy: 0.8587 - val_loss: 0.3035 - val_accuracy: 0.8739 - lr: 1.0000e-04
# Epoch 56/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3187 - accuracy: 0.8618 - val_loss: 0.3027 - val_accuracy: 0.8751 - lr: 1.0000e-04
# Epoch 57/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3139 - accuracy: 0.8644 - val_loss: 0.2985 - val_accuracy: 0.8761 - lr: 1.0000e-04
# Epoch 58/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3139 - accuracy: 0.8643 - val_loss: 0.3088 - val_accuracy: 0.8658 - lr: 1.0000e-04
# Epoch 59/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3104 - accuracy: 0.8664 - val_loss: 0.3112 - val_accuracy: 0.8686 - lr: 1.0000e-04
# Epoch 60/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3087 - accuracy: 0.8667 - val_loss: 0.2921 - val_accuracy: 0.8744 - lr: 1.0000e-04
# Epoch 61/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3067 - accuracy: 0.8668 - val_loss: 0.2928 - val_accuracy: 0.8790 - lr: 1.0000e-04
# Epoch 62/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.3024 - accuracy: 0.8696 - val_loss: 0.2985 - val_accuracy: 0.8778 - lr: 1.0000e-04
# Epoch 63/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2997 - accuracy: 0.8709 - val_loss: 0.2879 - val_accuracy: 0.8838 - lr: 1.0000e-04
# Epoch 64/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2974 - accuracy: 0.8727 - val_loss: 0.2952 - val_accuracy: 0.8758 - lr: 1.0000e-04
# Epoch 65/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2970 - accuracy: 0.8710 - val_loss: 0.2852 - val_accuracy: 0.8823 - lr: 1.0000e-04
# Epoch 66/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2893 - accuracy: 0.8759 - val_loss: 0.2841 - val_accuracy: 0.8845 - lr: 1.0000e-04
# Epoch 67/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2910 - accuracy: 0.8756 - val_loss: 0.2763 - val_accuracy: 0.8854 - lr: 1.0000e-04
# Epoch 68/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2918 - accuracy: 0.8739 - val_loss: 0.2819 - val_accuracy: 0.8852 - lr: 1.0000e-04
# Epoch 69/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2845 - accuracy: 0.8783 - val_loss: 0.2783 - val_accuracy: 0.8835 - lr: 1.0000e-04
# Epoch 70/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2827 - accuracy: 0.8786 - val_loss: 0.2683 - val_accuracy: 0.8912 - lr: 1.0000e-04
# Epoch 71/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2823 - accuracy: 0.8788 - val_loss: 0.3000 - val_accuracy: 0.8715 - lr: 1.0000e-04
# Epoch 72/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2766 - accuracy: 0.8818 - val_loss: 0.2682 - val_accuracy: 0.8881 - lr: 1.0000e-04
# Epoch 73/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2754 - accuracy: 0.8826 - val_loss: 0.2747 - val_accuracy: 0.8876 - lr: 1.0000e-04
# Epoch 74/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2740 - accuracy: 0.8821 - val_loss: 0.2789 - val_accuracy: 0.8799 - lr: 1.0000e-04
# Epoch 75/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2708 - accuracy: 0.8823 - val_loss: 0.2736 - val_accuracy: 0.8859 - lr: 1.0000e-04
# Epoch 76/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2676 - accuracy: 0.8854 - val_loss: 0.2721 - val_accuracy: 0.8871 - lr: 1.0000e-04
# Epoch 77/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2666 - accuracy: 0.8839 - val_loss: 0.2572 - val_accuracy: 0.8936 - lr: 1.0000e-04
# Epoch 78/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2636 - accuracy: 0.8857 - val_loss: 0.2514 - val_accuracy: 0.8953 - lr: 1.0000e-04
# Epoch 79/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2626 - accuracy: 0.8870 - val_loss: 0.2824 - val_accuracy: 0.8799 - lr: 1.0000e-04
# Epoch 80/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2580 - accuracy: 0.8897 - val_loss: 0.2743 - val_accuracy: 0.8852 - lr: 1.0000e-04
# Epoch 81/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2564 - accuracy: 0.8911 - val_loss: 0.2472 - val_accuracy: 0.8994 - lr: 1.0000e-04
# Epoch 82/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2566 - accuracy: 0.8904 - val_loss: 0.2477 - val_accuracy: 0.8948 - lr: 1.0000e-04
# Epoch 83/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2526 - accuracy: 0.8909 - val_loss: 0.2589 - val_accuracy: 0.8936 - lr: 1.0000e-04
# Epoch 84/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2534 - accuracy: 0.8932 - val_loss: 0.2457 - val_accuracy: 0.9023 - lr: 1.0000e-04
# Epoch 85/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2493 - accuracy: 0.8936 - val_loss: 0.2405 - val_accuracy: 0.9047 - lr: 1.0000e-04
# Epoch 86/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2469 - accuracy: 0.8933 - val_loss: 0.2303 - val_accuracy: 0.9090 - lr: 1.0000e-04
# Epoch 87/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2453 - accuracy: 0.8941 - val_loss: 0.2414 - val_accuracy: 0.9035 - lr: 1.0000e-04
# Epoch 88/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2416 - accuracy: 0.8962 - val_loss: 0.2280 - val_accuracy: 0.9073 - lr: 1.0000e-04
# Epoch 89/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2386 - accuracy: 0.8989 - val_loss: 0.2226 - val_accuracy: 0.9102 - lr: 1.0000e-04
# Epoch 90/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2377 - accuracy: 0.8977 - val_loss: 0.2200 - val_accuracy: 0.9121 - lr: 1.0000e-04
# Epoch 91/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2343 - accuracy: 0.9006 - val_loss: 0.2135 - val_accuracy: 0.9159 - lr: 1.0000e-04
# Epoch 92/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2328 - accuracy: 0.9009 - val_loss: 0.2181 - val_accuracy: 0.9126 - lr: 1.0000e-04
# Epoch 93/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2310 - accuracy: 0.9002 - val_loss: 0.2163 - val_accuracy: 0.9133 - lr: 1.0000e-04
# Epoch 94/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2287 - accuracy: 0.9041 - val_loss: 0.2145 - val_accuracy: 0.9143 - lr: 1.0000e-04
# Epoch 95/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2278 - accuracy: 0.9032 - val_loss: 0.2143 - val_accuracy: 0.9157 - lr: 1.0000e-04
# Epoch 96/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2254 - accuracy: 0.9025 - val_loss: 0.2089 - val_accuracy: 0.9167 - lr: 1.0000e-04
# Epoch 97/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2234 - accuracy: 0.9058 - val_loss: 0.2040 - val_accuracy: 0.9207 - lr: 1.0000e-04
# Epoch 98/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2200 - accuracy: 0.9062 - val_loss: 0.2006 - val_accuracy: 0.9195 - lr: 1.0000e-04
# Epoch 99/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2214 - accuracy: 0.9060 - val_loss: 0.2042 - val_accuracy: 0.9210 - lr: 1.0000e-04
# Epoch 100/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2061 - accuracy: 0.9128 - val_loss: 0.1961 - val_accuracy: 0.9224 - lr: 1.0000e-05
# Epoch 101/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2047 - accuracy: 0.9145 - val_loss: 0.1951 - val_accuracy: 0.9244 - lr: 1.0000e-05
# Epoch 102/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2056 - accuracy: 0.9147 - val_loss: 0.1957 - val_accuracy: 0.9260 - lr: 1.0000e-05
# Epoch 103/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2042 - accuracy: 0.9132 - val_loss: 0.1940 - val_accuracy: 0.9232 - lr: 1.0000e-05
# Epoch 104/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2026 - accuracy: 0.9145 - val_loss: 0.1959 - val_accuracy: 0.9224 - lr: 1.0000e-05
# Epoch 105/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2023 - accuracy: 0.9154 - val_loss: 0.1953 - val_accuracy: 0.9244 - lr: 1.0000e-05
# Epoch 106/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2022 - accuracy: 0.9152 - val_loss: 0.1936 - val_accuracy: 0.9251 - lr: 1.0000e-05
# Epoch 107/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2028 - accuracy: 0.9142 - val_loss: 0.1950 - val_accuracy: 0.9217 - lr: 1.0000e-05
# Epoch 108/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2022 - accuracy: 0.9153 - val_loss: 0.1954 - val_accuracy: 0.9241 - lr: 1.0000e-05
# Epoch 109/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2000 - accuracy: 0.9144 - val_loss: 0.1928 - val_accuracy: 0.9256 - lr: 1.0000e-05
# Epoch 110/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2002 - accuracy: 0.9166 - val_loss: 0.1916 - val_accuracy: 0.9248 - lr: 1.0000e-05
# Epoch 111/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2020 - accuracy: 0.9138 - val_loss: 0.1911 - val_accuracy: 0.9265 - lr: 1.0000e-05
# Epoch 112/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2017 - accuracy: 0.9162 - val_loss: 0.1934 - val_accuracy: 0.9222 - lr: 1.0000e-05
# Epoch 113/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2007 - accuracy: 0.9172 - val_loss: 0.1906 - val_accuracy: 0.9256 - lr: 1.0000e-05
# Epoch 114/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1998 - accuracy: 0.9165 - val_loss: 0.1902 - val_accuracy: 0.9258 - lr: 1.0000e-05
# Epoch 115/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1999 - accuracy: 0.9163 - val_loss: 0.1897 - val_accuracy: 0.9234 - lr: 1.0000e-05
# Epoch 116/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2009 - accuracy: 0.9169 - val_loss: 0.1900 - val_accuracy: 0.9256 - lr: 1.0000e-05
# Epoch 117/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1986 - accuracy: 0.9166 - val_loss: 0.1963 - val_accuracy: 0.9193 - lr: 1.0000e-05
# Epoch 118/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.2003 - accuracy: 0.9168 - val_loss: 0.1895 - val_accuracy: 0.9244 - lr: 1.0000e-05
# Epoch 119/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1979 - accuracy: 0.9162 - val_loss: 0.1921 - val_accuracy: 0.9207 - lr: 1.0000e-05
# Epoch 120/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1986 - accuracy: 0.9165 - val_loss: 0.1883 - val_accuracy: 0.9253 - lr: 1.0000e-05
# Epoch 121/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1982 - accuracy: 0.9168 - val_loss: 0.1878 - val_accuracy: 0.9275 - lr: 1.0000e-05
# Epoch 122/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1966 - accuracy: 0.9174 - val_loss: 0.1887 - val_accuracy: 0.9229 - lr: 1.0000e-05
# Epoch 123/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1971 - accuracy: 0.9162 - val_loss: 0.1871 - val_accuracy: 0.9258 - lr: 1.0000e-05
# Epoch 124/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1984 - accuracy: 0.9164 - val_loss: 0.1913 - val_accuracy: 0.9217 - lr: 1.0000e-05
# Epoch 125/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1965 - accuracy: 0.9188 - val_loss: 0.1872 - val_accuracy: 0.9272 - lr: 1.0000e-05
# Epoch 126/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1978 - accuracy: 0.9175 - val_loss: 0.1866 - val_accuracy: 0.9263 - lr: 1.0000e-05
# Epoch 127/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1978 - accuracy: 0.9169 - val_loss: 0.1867 - val_accuracy: 0.9251 - lr: 1.0000e-05
# Epoch 128/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1947 - accuracy: 0.9185 - val_loss: 0.1857 - val_accuracy: 0.9241 - lr: 1.0000e-05
# Epoch 129/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1965 - accuracy: 0.9178 - val_loss: 0.1856 - val_accuracy: 0.9282 - lr: 1.0000e-05
# Epoch 130/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1963 - accuracy: 0.9175 - val_loss: 0.1863 - val_accuracy: 0.9248 - lr: 1.0000e-05
# Epoch 131/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1952 - accuracy: 0.9175 - val_loss: 0.1852 - val_accuracy: 0.9263 - lr: 1.0000e-05
# Epoch 132/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1939 - accuracy: 0.9189 - val_loss: 0.1852 - val_accuracy: 0.9289 - lr: 1.0000e-05
# Epoch 133/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1957 - accuracy: 0.9190 - val_loss: 0.1845 - val_accuracy: 0.9275 - lr: 1.0000e-05
# Epoch 134/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1947 - accuracy: 0.9178 - val_loss: 0.1844 - val_accuracy: 0.9256 - lr: 1.0000e-05
# Epoch 135/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1959 - accuracy: 0.9190 - val_loss: 0.1838 - val_accuracy: 0.9270 - lr: 1.0000e-05
# Epoch 136/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1944 - accuracy: 0.9198 - val_loss: 0.1839 - val_accuracy: 0.9263 - lr: 1.0000e-05
# Epoch 137/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1953 - accuracy: 0.9184 - val_loss: 0.1840 - val_accuracy: 0.9256 - lr: 1.0000e-05
# Epoch 138/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1945 - accuracy: 0.9178 - val_loss: 0.1837 - val_accuracy: 0.9260 - lr: 1.0000e-05
# Epoch 139/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1942 - accuracy: 0.9187 - val_loss: 0.1829 - val_accuracy: 0.9282 - lr: 1.0000e-05
# Epoch 140/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1935 - accuracy: 0.9189 - val_loss: 0.1831 - val_accuracy: 0.9272 - lr: 1.0000e-05
# Epoch 141/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1925 - accuracy: 0.9201 - val_loss: 0.1833 - val_accuracy: 0.9294 - lr: 1.0000e-05
# Epoch 142/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1944 - accuracy: 0.9179 - val_loss: 0.1825 - val_accuracy: 0.9275 - lr: 1.0000e-05
# Epoch 143/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1952 - accuracy: 0.9177 - val_loss: 0.1829 - val_accuracy: 0.9284 - lr: 1.0000e-05
# Epoch 144/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1940 - accuracy: 0.9192 - val_loss: 0.1813 - val_accuracy: 0.9277 - lr: 1.0000e-05
# Epoch 145/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1913 - accuracy: 0.9196 - val_loss: 0.1818 - val_accuracy: 0.9287 - lr: 1.0000e-05
# Epoch 146/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1898 - accuracy: 0.9211 - val_loss: 0.1826 - val_accuracy: 0.9260 - lr: 1.0000e-05
# Epoch 147/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1930 - accuracy: 0.9192 - val_loss: 0.1804 - val_accuracy: 0.9301 - lr: 1.0000e-05
# Epoch 148/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1901 - accuracy: 0.9204 - val_loss: 0.1812 - val_accuracy: 0.9275 - lr: 1.0000e-05
# Epoch 149/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1919 - accuracy: 0.9198 - val_loss: 0.1808 - val_accuracy: 0.9284 - lr: 1.0000e-05
# Epoch 150/150
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.1911 - accuracy: 0.9198 - val_loss: 0.1815 - val_accuracy: 0.9277 - lr: 1.0000e-05

# %% [markdown]
# # Evaluation
#
# ---
#
# In this stage we will test and evaluate the model on an unseen data.
# this data in a small portion of our data and it consist of data that is labeled 1 and 0.

# %% [markdown]
# Here we are testing the model on the data that is labeled 1 and we can see the accuracy of the model in the predicion process.

# %%
model.evaluate(val1_data,val1_labels,batch_size=batchSize, verbose = 1)

probability_model = keras.models.Sequential([
    model,keras.layers.Softmax()
])

predictions = probability_model(val1_data)

pre0 = predictions[0]

print(pre0)

label0 = np.argmax(pre0)

print(label0)
# Out:
#  1/15 [=>............................] - ETA: 3s - loss: 0.2472 - accuracy: 0.8750
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1457 - accuracy: 0.9541
# tf.Tensor([0.29647228 0.7035277 ], shape=(2,), dtype=float32)
# 1

# %% [markdown]
# Here we are testing the model on the data that is labeled 0 and we can see the accuracy of the model in the predicion process.

# %%
model.evaluate(val0_data,val0_labels,batch_size=batchSize, verbose = 1)

probability_model = keras.models.Sequential([
    model,keras.layers.Softmax()
])

predictions = probability_model(val0_data)

pre0 = predictions[0]

print(pre0)

label0 = np.argmax(pre0)

print(label0)
# Out:
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2366 - accuracy: 0.8829
# tf.Tensor([0.6508122 0.3491878], shape=(2,), dtype=float32)
# 0

# %%
predictions = model.predict(x=val0_data,verbose= 1)

for i in predictions:
  print(i)

# %%
predictions = model.predict(x=val1_data,verbose= 1)

for i in predictions:
  print(i)

# %% [markdown]
# Saving the model in h5 format.

# %%
model.save("Deep_LSTM32_1x1_rand_40.h5")
